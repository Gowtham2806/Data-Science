# %%
import pandas as pd
import numpy as np

# %%
tree_census = pd.read_csv('street-tree-census-data.csv')

# %%
tree_census.head(4)
# Out:
#    tree_id  block_id               created_at  tree_dbh  stump_diam curb_loc  \
# 0   180683    348711  2015-08-27T00:00:00.000         3           0   OnCurb
# 1   200540    315986  2015-09-03T00:00:00.000        21           0   OnCurb
# 2   204026    218365  2015-09-05T00:00:00.000         3           0   OnCurb
# 3   204337    217969  2015-09-05T00:00:00.000        10           0   OnCurb
#
#   status health                           spc_latin   spc_common  ...  \
# 0  Alive   Fair                         Acer rubrum    red maple  ...
# 1  Alive   Fair                   Quercus palustris      pin oak  ...
# 2  Alive   Good  Gleditsia triacanthos var. inermis  honeylocust  ...
# 3  Alive   Good  Gleditsia triacanthos var. inermis  honeylocust  ...
#
#    boro_ct     state   latitude  longitude         x_sp         y_sp  \
# 0  4073900  New York  40.723092 -73.844215  1027431.148  202756.7687
# 1  4097300  New York  40.794111 -73.818679  1034455.701  228644.8374
# 2  3044900  New York  40.717581 -73.936608  1001822.831  200716.8913
# 3  3044900  New York  40.713537 -73.934456  1002420.358  199244.2531
#
#   council district census tract        bin           bbl
# 0             29.0        739.0  4052307.0  4.022210e+09
# 1             19.0        973.0  4101931.0  4.044750e+09
# 2             34.0        449.0  3338310.0  3.028870e+09
# 3             34.0        449.0  3338342.0  3.029250e+09
#
# [4 rows x 45 columns]

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census.isnull().sum()
# Out:
# tree_id                 0
# block_id                0
# created_at              0
# tree_dbh                0
# stump_diam              0
# curb_loc                0
# status                  0
# health              31616
# spc_latin           31619
# spc_common          31619
# steward             31615
# guards              31616
# sidewalk            31616
# user_type               0
# problems            31664
# root_stone              0
# root_grate              0
# root_other              0
# trunk_wire              0
# trnk_light              0
# trnk_other              0
# brch_light              0
# brch_shoe               0
# brch_other              0
# address                 0
# postcode                0
# zip_city                0
# community board         0
# borocode                0
# borough                 0
# cncldist                0
# st_assem                0
# st_senate               0
# nta                     0
# nta_name                0
# boro_ct                 0
# state                   0
# latitude                0
# longitude               0
# x_sp                    0
# y_sp                    0
# council district     6519
# census tract         6519
# bin                  9559
# bbl                  9559
# dtype: int64

# %%
tree_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683788 entries, 0 to 683787
# Data columns (total 45 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   tree_id           683788 non-null  int64
#  1   block_id          683788 non-null  int64
#  2   created_at        683788 non-null  object
#  3   tree_dbh          683788 non-null  int64
#  4   stump_diam        683788 non-null  int64
#  5   curb_loc          683788 non-null  object
#  6   status            683788 non-null  object
#  7   health            652172 non-null  object
#  8   spc_latin         652169 non-null  object
#  9   spc_common        652169 non-null  object
#  10  steward           652173 non-null  object
#  11  guards            652172 non-null  object
#  12  sidewalk          652172 non-null  object
#  13  user_type         683788 non-null  object
#  14  problems          652124 non-null  object
#  15  root_stone        683788 non-null  object
#  16  root_grate        683788 non-null  object
#  17  root_other        683788 non-null  object
#  18  trunk_wire        683788 non-null  object
#  19  trnk_light        683788 non-null  object
#  20  trnk_other        683788 non-null  object
#  21  brch_light        683788 non-null  object
#  22  brch_shoe         683788 non-null  object
#  23  brch_other        683788 non-null  object
#  24  address           683788 non-null  object
#  25  postcode          683788 non-null  int64
#  26  zip_city          683788 non-null  object
#  27  community board   683788 non-null  int64
#  28  borocode          683788 non-null  int64
#  29  borough           683788 non-null  object
#  30  cncldist          683788 non-null  int64
#  31  st_assem          683788 non-null  int64
#  32  st_senate         683788 non-null  int64
#  33  nta               683788 non-null  object
#  34  nta_name          683788 non-null  object
#  35  boro_ct           683788 non-null  int64
#  36  state             683788 non-null  object
#  37  latitude          683788 non-null  float64
#  38  longitude         683788 non-null  float64
#  39  x_sp              683788 non-null  float64
#  40  y_sp              683788 non-null  float64
#  41  council district  677269 non-null  float64
#  42  census tract      677269 non-null  float64
#  43  bin               674229 non-null  float64
#  44  bbl               674229 non-null  float64
# dtypes: float64(8), int64(11), object(26)
# memory usage: 234.8+ MB

# %%
tree_census.isnull()
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam  curb_loc  status  \
# 0         False     False       False     False       False     False   False
# 1         False     False       False     False       False     False   False
# 2         False     False       False     False       False     False   False
# 3         False     False       False     False       False     False   False
# 4         False     False       False     False       False     False   False
# ...         ...       ...         ...       ...         ...       ...     ...
# 683783    False     False       False     False       False     False   False
# 683784    False     False       False     False       False     False   False
# 683785    False     False       False     False       False     False   False
# 683786    False     False       False     False       False     False   False
# 683787    False     False       False     False       False     False   False
#
#         health  spc_latin  spc_common  ...  boro_ct  state  latitude  \
# 0        False      False       False  ...    False  False     False
# 1        False      False       False  ...    False  False     False
# 2        False      False       False  ...    False  False     False
# 3        False      False       False  ...    False  False     False
# 4        False      False       False  ...    False  False     False
# ...        ...        ...         ...  ...      ...    ...       ...
# 683783   False      False       False  ...    False  False     False
# 683784   False      False       False  ...    False  False     False
# 683785   False      False       False  ...    False  False     False
# 683786   False      False       False  ...    False  False     False
# 683787   False      False       False  ...    False  False     False
#
#         longitude   x_sp   y_sp  council district  census tract    bin    bbl
# 0           False  False  False             False         False  False  False
# 1           False  False  False             False         False  False  False
# 2           False  False  False             False         False  False  False
# 3           False  False  False             False         False  False  False
# 4           False  False  False             False         False  False  False
# ...           ...    ...    ...               ...           ...    ...    ...
# 683783      False  False  False             False         False  False  False
# 683784      False  False  False             False         False  False  False
# 683785      False  False  False             False         False  False  False
# 683786      False  False  False             False         False  False  False
# 683787      False  False  False             False         False  False  False
#
# [683788 rows x 45 columns]

# %%
tree_census['health'].unique()
# Out:
# array(['Fair', 'Good', 'Poor', nan], dtype=object)

# %%
tree_census.problems.unique()
# Out:
# array(['None', 'Stones', 'MetalGrates', 'RootOther', 'Stones,BranchOther',
#        'TrunkLights,BranchLights', 'RootOther,TrunkOther,BranchOther',
#        'BranchOther', 'Stones,BranchLights', 'TrunkOther,BranchLights',
#        'MetalGrates,TrunkOther', nan, 'TrunkOther', 'Stones,WiresRope',
#        'BranchLights', 'WiresRope,BranchOther', 'RootOther,BranchOther',
#        'Stones,WiresRope,BranchLights', 'WiresRope',
#        'WiresRope,BranchLights', 'Stones,TrunkOther',
#        'WiresRope,TrunkLights,BranchLights', 'Stones,RootOther',
#        'Stones,BranchLights,BranchOther', 'Stones,RootOther,BranchLights',
#        'MetalGrates,BranchOther', 'Stones,RootOther,TrunkOther',
#        'RootOther,TrunkOther',
#        'Stones,TrunkOther,BranchLights,BranchOther',
#        'Stones,TrunkOther,BranchOther', 'RootOther,BranchLights',
#        'TrunkOther,BranchOther', 'RootOther,WiresRope,BranchLights',
#        'Stones,TrunkOther,BranchLights', 'BranchLights,Sneakers',
#        'Stones,RootOther,TrunkOther,BranchLights',
#        'MetalGrates,TrunkOther,BranchOther', 'TrunkLights,BranchOther',
#        'TrunkLights', 'Stones,RootOther,BranchOther',
#        'RootOther,WiresRope', 'BranchLights,BranchOther',
#        'Stones,MetalGrates', 'RootOther,TrunkOther,BranchLights',
#        'Stones,WiresRope,TrunkOther,BranchLights',
#        'WiresRope,TrunkOther,BranchOther',
#        'RootOther,WiresRope,TrunkOther,BranchLights',
#        'RootOther,TrunkOther,BranchLights,BranchOther',
#        'MetalGrates,RootOther,TrunkOther', 'Stones,WiresRope,TrunkOther',
#        'MetalGrates,RootOther,TrunkOther,BranchOther',
#        'Stones,RootOther,WiresRope,BranchLights', 'WiresRope,TrunkOther',
#        'RootOther,WiresRope,TrunkOther', 'MetalGrates,WiresRope',
#        'Stones,RootOther,WiresRope,TrunkOther',
#        'Stones,RootOther,TrunkOther,BranchOther',
#        'Stones,WiresRope,BranchOther',
#        'RootOther,BranchLights,BranchOther',
#        'Stones,RootOther,WiresRope,TrunkLights,BranchLights',
#        'RootOther,WiresRope,TrunkOther,BranchLights,BranchOther',
#        'WiresRope,TrunkOther,BranchLights,BranchOther',
#        'Stones,RootOther,WiresRope,BranchOther', 'MetalGrates,RootOther',
#        'Stones,TrunkLights', 'Stones,MetalGrates,WiresRope,BranchLights',
#        'Stones,WiresRope,BranchLights,BranchOther',
#        'TrunkOther,BranchLights,BranchOther', 'TrunkLights,TrunkOther',
#        'Stones,RootOther,TrunkLights,BranchLights',
#        'Stones,TrunkLights,BranchLights',
#        'WiresRope,BranchLights,BranchOther', 'WiresRope,TrunkLights',
#        'Stones,RootOther,TrunkOther,BranchLights,BranchOther',
#        'TrunkOther,Sneakers',
#        'RootOther,WiresRope,TrunkOther,BranchOther',
#        'RootOther,TrunkLights,BranchLights', 'RootOther,Sneakers',
#        'Stones,RootOther,Sneakers,BranchOther',
#        'MetalGrates,WiresRope,BranchOther',
#        'RootOther,TrunkLights,BranchOther',
#        'RootOther,WiresRope,BranchOther',
#        'Stones,RootOther,WiresRope,TrunkOther,BranchLights,BranchOther',
#        'MetalGrates,BranchLights',
#        'Stones,TrunkLights,BranchLights,BranchOther',
#        'Stones,MetalGrates,RootOther', 'Stones,Sneakers',
#        'Stones,TrunkLights,BranchOther',
#        'Stones,RootOther,BranchLights,BranchOther', 'Sneakers',
#        'Stones,RootOther,Sneakers', 'MetalGrates,TrunkOther,BranchLights',
#        'MetalGrates,TrunkLights,BranchLights',
#        'WiresRope,TrunkOther,BranchLights,Sneakers',
#        'MetalGrates,RootOther,BranchOther', 'Stones,RootOther,WiresRope',
#        'Stones,WiresRope,BranchLights,Sneakers',
#        'WiresRope,TrunkOther,BranchLights',
#        'Stones,RootOther,WiresRope,TrunkOther,BranchLights',
#        'Stones,RootOther,WiresRope,BranchLights,BranchOther',
#        'RootOther,WiresRope,BranchLights,BranchOther',
#        'Stones,MetalGrates,TrunkOther',
#        'RootOther,TrunkLights,TrunkOther,BranchLights,BranchOther',
#        'MetalGrates,Sneakers',
#        'Stones,RootOther,WiresRope,TrunkOther,BranchOther',
#        'Stones,WiresRope,TrunkOther,BranchLights,BranchOther',
#        'MetalGrates,RootOther,WiresRope,TrunkLights,BranchLights,BranchOther',
#        'Stones,WiresRope,TrunkOther,BranchOther',
#        'MetalGrates,RootOther,WiresRope,BranchOther',
#        'MetalGrates,WiresRope,TrunkLights,BranchLights,BranchOther',
#        'TrunkLights,TrunkOther,BranchLights', 'WiresRope,Sneakers',
#        'RootOther,WiresRope,TrunkLights,BranchOther',
#        'MetalGrates,RootOther,BranchLights',
#        'Stones,MetalGrates,BranchLights', 'Stones,RootOther,TrunkLights',
#        'Sneakers,BranchOther', 'Stones,RootOther,TrunkOther,Sneakers',
#        'Stones,WiresRope,TrunkLights,BranchLights',
#        'Stones,BranchLights,Sneakers',
#        'BranchLights,Sneakers,BranchOther',
#        'MetalGrates,RootOther,TrunkLights,BranchLights',
#        'Stones,RootOther,BranchLights,Sneakers',
#        'Stones,TrunkLights,TrunkOther,BranchLights',
#        'RootOther,TrunkLights', 'TrunkLights,Sneakers',
#        'TrunkLights,BranchLights,BranchOther',
#        'Stones,MetalGrates,RootOther,BranchOther',
#        'Stones,RootOther,WiresRope,TrunkLights',
#        'Stones,RootOther,WiresRope,TrunkLights,BranchOther',
#        'RootOther,TrunkLights,TrunkOther,BranchLights',
#        'RootOther,WiresRope,TrunkLights',
#        'TrunkLights,TrunkOther,BranchLights,BranchOther',
#        'Stones,MetalGrates,WiresRope,TrunkLights,BranchLights',
#        'Stones,MetalGrates,TrunkOther,BranchOther',
#        'Stones,TrunkOther,Sneakers', 'Stones,MetalGrates,WiresRope',
#        'Stones,MetalGrates,RootOther,TrunkOther',
#        'Stones,RootOther,TrunkLights,TrunkOther,BranchLights',
#        'TrunkOther,BranchLights,Sneakers,BranchOther',
#        'Stones,Sneakers,BranchOther',
#        'RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights',
#        'MetalGrates,RootOther,TrunkOther,BranchLights',
#        'WiresRope,TrunkLights,TrunkOther,BranchLights',
#        'Stones,MetalGrates,TrunkOther,BranchLights',
#        'Stones,TrunkLights,TrunkOther,BranchOther',
#        'Stones,TrunkLights,TrunkOther',
#        'MetalGrates,WiresRope,BranchLights',
#        'RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther',
#        'Stones,MetalGrates,BranchOther',
#        'Stones,MetalGrates,RootOther,TrunkOther,BranchOther',
#        'RootOther,WiresRope,TrunkLights,BranchLights',
#        'Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchOther',
#        'MetalGrates,BranchLights,BranchOther',
#        'RootOther,TrunkOther,Sneakers,BranchOther',
#        'Stones,RootOther,TrunkOther,Sneakers,BranchOther',
#        'RootOther,TrunkLights,TrunkOther,BranchOther',
#        'RootOther,TrunkOther,Sneakers',
#        'TrunkLights,TrunkOther,BranchOther',
#        'Stones,WiresRope,TrunkLights', 'MetalGrates,WiresRope,TrunkOther',
#        'WiresRope,TrunkLights,BranchOther',
#        'WiresRope,TrunkOther,Sneakers',
#        'WiresRope,TrunkLights,TrunkOther',
#        'Stones,RootOther,WiresRope,BranchLights,Sneakers',
#        'Stones,MetalGrates,TrunkLights,BranchLights',
#        'Stones,MetalGrates,TrunkLights,TrunkOther,BranchLights',
#        'Stones,MetalGrates,TrunkLights,BranchLights,BranchOther',
#        'RootOther,BranchLights,Sneakers',
#        'Stones,WiresRope,TrunkLights,BranchLights,BranchOther',
#        'Stones,MetalGrates,TrunkLights,TrunkOther',
#        'Stones,MetalGrates,TrunkLights',
#        'Stones,RootOther,WiresRope,TrunkLights,BranchLights,BranchOther',
#        'MetalGrates,WiresRope,TrunkLights,BranchLights',
#        'MetalGrates,WiresRope,TrunkOther,BranchLights',
#        'TrunkOther,Sneakers,BranchOther',
#        'Stones,MetalGrates,WiresRope,TrunkOther,BranchLights',
#        'Stones,TrunkLights,TrunkOther,BranchLights,BranchOther',
#        'Stones,MetalGrates,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther',
#        'Stones,WiresRope,TrunkLights,TrunkOther,BranchLights',
#        'Stones,MetalGrates,RootOther,WiresRope,TrunkOther,BranchLights',
#        'Stones,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther',
#        'Stones,MetalGrates,BranchLights,BranchOther',
#        'Stones,WiresRope,Sneakers',
#        'Stones,MetalGrates,WiresRope,TrunkLights,BranchLights,BranchOther',
#        'TrunkOther,BranchLights,Sneakers',
#        'MetalGrates,RootOther,WiresRope,TrunkOther,BranchOther',
#        'Stones,MetalGrates,WiresRope,TrunkOther',
#        'Stones,MetalGrates,RootOther,WiresRope,TrunkOther',
#        'Stones,MetalGrates,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,Sneakers,BranchOther',
#        'Stones,TrunkOther,BranchLights,Sneakers',
#        'WiresRope,TrunkLights,TrunkOther,BranchOther',
#        'Stones,MetalGrates,WiresRope,BranchOther',
#        'Stones,RootOther,TrunkLights,TrunkOther',
#        'Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights',
#        'Stones,MetalGrates,Sneakers', 'MetalGrates,RootOther,WiresRope',
#        'Stones,WiresRope,TrunkLights,BranchOther',
#        'MetalGrates,WiresRope,TrunkLights,TrunkOther',
#        'Stones,MetalGrates,RootOther,WiresRope,BranchLights',
#        'Stones,MetalGrates,RootOther,BranchLights',
#        'Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther',
#        'Stones,WiresRope,TrunkLights,TrunkOther',
#        'WiresRope,TrunkLights,BranchLights,BranchOther',
#        'Stones,TrunkOther,Sneakers,BranchOther',
#        'MetalGrates,RootOther,TrunkLights', 'MetalGrates,TrunkLights',
#        'RootOther,TrunkLights,TrunkOther',
#        'Stones,TrunkOther,BranchLights,Sneakers,BranchOther',
#        'MetalGrates,TrunkLights,TrunkOther,BranchOther',
#        'MetalGrates,RootOther,TrunkLights,TrunkOther',
#        'MetalGrates,RootOther,TrunkLights,BranchOther',
#        'RootOther,WiresRope,Sneakers,BranchOther',
#        'MetalGrates,RootOther,TrunkLights,TrunkOther,BranchOther',
#        'MetalGrates,WiresRope,TrunkOther,BranchOther',
#        'MetalGrates,RootOther,TrunkOther,BranchLights,BranchOther',
#        'MetalGrates,RootOther,TrunkLights,TrunkOther,BranchLights,BranchOther',
#        'Stones,BranchLights,Sneakers,BranchOther',
#        'RootOther,WiresRope,TrunkLights,BranchLights,BranchOther',
#        'Stones,MetalGrates,RootOther,WiresRope,TrunkLights',
#        'Stones,MetalGrates,RootOther,WiresRope',
#        'MetalGrates,TrunkOther,BranchLights,BranchOther',
#        'Stones,RootOther,TrunkOther,BranchLights,Sneakers',
#        'Stones,RootOther,TrunkLights,BranchLights,BranchOther',
#        'MetalGrates,RootOther,WiresRope,TrunkOther',
#        'Stones,RootOther,BranchLights,Sneakers,BranchOther',
#        'TrunkLights,BranchLights,Sneakers',
#        'Stones,MetalGrates,RootOther,TrunkOther,BranchLights',
#        'Stones,MetalGrates,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther',
#        'WiresRope,BranchLights,Sneakers',
#        'MetalGrates,WiresRope,TrunkLights',
#        'Stones,RootOther,TrunkLights,TrunkOther,BranchOther',
#        'MetalGrates,TrunkOther,Sneakers'], dtype=object)

# %%
tree_census.problems.nunique()
# Out:
# 232

# %%
tree_census.shape
# Out:
# (683788, 45)

# %%
tree_census['tree_id'].nunique()
# Out:
# 683788

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subset = tree_census[['tree_id', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'steward', 'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other',]]

tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# 2       Gleditsia triacanthos var. inermis    1or2    Damage     None
# 3       Gleditsia triacanthos var. inermis    None    Damage   Stones
# 4                          Tilia americana    None    Damage   Stones
# ...                                    ...     ...       ...      ...
# 683783                   Quercus palustris    None    Damage     None
# 683784                 Cladrastis kentukea    1or2  NoDamage     None
# 683785                         Acer rubrum    None    Damage     None
# 683786                         Acer rubrum    None  NoDamage     None
# 683787                         Acer rubrum    None  NoDamage     None
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# 1              No        No         No
# 2              No        No         No
# 3              No        No         No
# 4              No        No         No
# ...           ...       ...        ...
# 683783         No        No         No
# 683784         No        No         No
# 683785         No        No         No
# 683786         No        No         No
# 683787         No        No         No
#
# [683788 rows x 19 columns]

# %%
tree_census_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683788 entries, 0 to 683787
# Data columns (total 19 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   tree_id     683788 non-null  int64
#  1   tree_dbh    683788 non-null  int64
#  2   stump_diam  683788 non-null  int64
#  3   curb_loc    683788 non-null  object
#  4   status      683788 non-null  object
#  5   health      652172 non-null  object
#  6   spc_latin   652169 non-null  object
#  7   steward     652173 non-null  object
#  8   sidewalk    652172 non-null  object
#  9   problems    652124 non-null  object
#  10  root_stone  683788 non-null  object
#  11  root_grate  683788 non-null  object
#  12  root_other  683788 non-null  object
#  13  trunk_wire  683788 non-null  object
#  14  trnk_light  683788 non-null  object
#  15  trnk_other  683788 non-null  object
#  16  brch_light  683788 non-null  object
#  17  brch_shoe   683788 non-null  object
#  18  brch_other  683788 non-null  object
# dtypes: int64(3), object(16)
# memory usage: 99.1+ MB

# %%
tree_census_subset.isnull().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isnull()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 37         NaN      NaN      NaN         No         No         No         No
# 57         NaN      NaN      NaN         No         No         No         No
# 196        NaN      NaN      NaN         No         No         No         No
# 209        NaN      NaN      NaN         No         No         No         No
# 239        NaN      NaN      NaN         No         No         No         No
# ...        ...      ...      ...        ...        ...        ...        ...
# 683693     NaN      NaN      NaN         No         No         No         No
# 683695     NaN      NaN      NaN         No         No         No         No
# 683697     NaN      NaN      NaN         No         No         No         No
# 683698     NaN      NaN      NaN         No         No         No         No
# 683699     NaN      NaN      NaN         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 37             No         No         No        No         No
# 57             No         No         No        No         No
# 196            No         No         No        No         No
# 209            No         No         No        No         No
# 239            No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 683693         No         No         No        No         No
# 683695         No         No         No        No         No
# 683697         No         No         No        No         No
# 683698         No         No         No        No         No
# 683699         No         No         No        No         No
#
# [31616 rows x 19 columns]

# %%
tree_census_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
tree_census_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
tree_census_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'tree_dbh'}>],
#        [<AxesSubplot:title={'center':'stump_diam'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
tree_census_subset['status'].value_counts()
# Out:
# Alive    652173
# Stump     17654
# Dead      13961
# Name: status, dtype: int64

# %%
tree_census_subset['health'].value_counts()
# Out:
# Good    528850
# Fair     96504
# Poor     26818
# Name: health, dtype: int64

# %%
tree_census_subset['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
tree_census_subset['curb_loc'].value_counts()
# Out:
# OnCurb            656896
# OffsetFromCurb     26892
# Name: curb_loc, dtype: int64

# %%
tree_census_subset['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64
